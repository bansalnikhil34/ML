# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
url="https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %%
# read the above file

# %%
df=pd.read_csv(url,sep='\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# print the first five and last seven records

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
# print total records and type of vairables

# %%
#df.info()

#or 

df.shape[0] # 0 for rows 1 for column
# Out:
# 4622

# %%
# print the name of all the columns

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#how is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# which was the most ordered item ? and how many items were ordered

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.groupby('item_name').sum().sort_values('quantity',ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
# what was the most ordered item in the choice_desc column

# %%
df.groupby('choice_description').sum().sort_values('quantity',ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
# turn the item_price into float

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df['item_price']=df['item_price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-3b968290607b> in <module>
# ----> 1 df['item_price']=df['item_price'].astype(float)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
price= lambda x: float(x[1:-1])
df['item_price']= df['item_price'].apply(price)

# %%
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
# How much was the revenue for the period in the dataset

# %%
df['revenue']=df['quantity']*df['item_price']
df['revenue'].sum()
# Out:
# 39237.02

# %%
# print a data frame with only two columns item_name and item_price

# %%
df[['item_name','item_price']].head()
# Out:
#                                item_name  item_price
# 0           Chips and Fresh Tomato Salsa        2.39
# 1                                   Izze        3.39
# 2                       Nantucket Nectar        3.39
# 3  Chips and Tomatillo-Green Chili Salsa        2.39
# 4                           Chicken Bowl       16.98

# %%
# delete the duplicates in item_name and quatity

# %%
df.drop_duplicates(['item_name','quantity'])
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description  item_price  revenue
# 0                                                   NaN        2.39     2.39
# ...

# %%
# select only the products with quantity equals to 1

# %%
df[df['quantity']==1]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  revenue
# 0                                                   NaN        2.39     2.39
# ...

# %%
# sort the items from most to less expensive

# %%
df.sort_values('item_price',ascending=False)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3936      1578         1                   Canned Soda
# 2922      1162         1                 Bottled Water
# 1396       567         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# 1457       591         1                   Canned Soda
#
#                                      choice_description  item_price  revenue
# 3598                                                NaN       44.25   663.75
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25   105.75
# ...

# %%
# what was the quantity of the most expensive item ordered

# %%
df.sort_values('item_price',ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price  revenue
# 3598       44.25   663.75

# %%
# how many times were veggie salad bowl ordered

# %%
df[df.item_name == 'Veggie Bowl'].groupby('item_name').sum()
# Out:
#              order_id  quantity  item_price  revenue
# item_name
# Veggie Bowl     72270        87      867.99   901.95

# %%
df[df.item_name == 'Veggie Bowl'].groupby('item_name').sum()[['quantity']]
# Out:
#              quantity
# item_name
# Veggie Bowl        87

# %%
#

# %%
url1 = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'

# %%
df1 = pd.read_csv(url1,sep=',')

# %%
df1.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# which continent drink more beer on averge?

# %%
df1.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
# for each continent print the statitics for wine consumption

# %%
df1.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
# crime dataset

# %%
url2 ="https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv"

# %%
df2 = pd.read_csv(url2,sep=',')

# %%
df2.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
# convert the type of the column year to datetime64

# %%
df2['Year']=pd.to_datetime(df2.Year,format='%Y')

# %%
df2.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
# set the Year column as the index of the dataframe

# %%
crime=df2.set_index('Year',drop=True)
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
#Group the year by decades and sum the values

# %%
# use resample to sum each decade

crime.resample('10AS').sum()
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
# use resample to get the max value for Population column

# %%
crime.resample('10AS')[['Population']].max()
# Out:
#             Population
# Year
# 1960-01-01   201385000
# 1970-01-01   220099000
# 1980-01-01   248239000
# 1990-01-01   272690813
# 2000-01-01   307006550
# 2010-01-01   318857056

# %%
crime.iloc[:3]
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# 1962-01-01         366800

# %%
crime.iloc[1,3]
# Out:
# 3198600

# %%
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
crime.loc["1960-01-01"]
# Out:
# Population            179323175
# Total                   3384200
# Violent                  288460
# Property                3095700
# Murder                     9110
# Forcible_Rape             17190
# Robbery                  107840
# Aggravated_assault       154320
# Burglary                 912100
# Larceny_Theft           1855400
# Vehicle_Theft            328200
# Name: 1960-01-01 00:00:00, dtype: int64

# %%
df1.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
beer=df1.set_index('country')

# %%
beer.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# Andorra                              12.4        EU
# Angola                                5.9        AF

# %%
# loc 

beer.loc[['Albania','Angola']]
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# Albania             89              132             54
# Angola             217               57             45
#
#          total_litres_of_pure_alcohol continent
# country
# Albania                           4.9        EU
# Angola                            5.9        AF

# %%
beer.loc['Albania':'Angola']
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# Albania             89              132             54
# Algeria             25                0             14
# Andorra            245              138            312
# Angola             217               57             45
#
#          total_litres_of_pure_alcohol continent
# country
# Albania                           4.9        EU
# Algeria                           0.7        AF
# Andorra                          12.4        EU
# Angola                            5.9        AF

# %%
# iloc

beer.iloc[2,3]
# Out:
# 0.7

# %%
beer.iloc[[2,3]
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# Algeria             25                0             14
# Andorra            245              138            312
#
#          total_litres_of_pure_alcohol continent
# country
# Algeria                           0.7        AF
# Andorra                          12.4        EU

# %%
beer.iloc[[2,3],[0,1]]
# Out:
#          beer_servings  spirit_servings
# country
# Algeria             25                0
# Andorra            245              138

# %%
beer.iloc[:4]
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# Andorra                              12.4        EU

# %%
crime.loc["1960-01-01":"1965-01-01"]
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
# 1965-01-01   193526000  4739400   387390   4352000    9960          23410
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
# ...

# %%
crime.loc[['1960-01-01','1965-01-01']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-247-4763af4074d4> in <module>
# ----> 1 crime.loc[['1960-01-01','1965-01-01']]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1951                     raise ValueError("Cannot index with multidimensional key")
#    1952
# -> 1953                 return self._getitem_iterable(key, axis=axis)
#    1954
#    1955             # nested tuple slicing
#
# ...

# %%
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
# return the first 3 rows of the dataframe

# %%
crime.iloc[:3]
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# 1962-01-01         366800

# %%
# select just the murder and robbery column

# %%
# 4th and 6th column
crime.iloc[:,[4,6]].head()
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %%
# 4 and 6th row
crime.iloc[[4,6]].head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
# 1966-01-01   195576000  5223500   430180   4793300   11040          25820
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1964-01-01   130390              203050   1213200        2514400
# 1966-01-01   157990              235330   1410100        2822000
#
#             Vehicle_Theft
# Year
# 1964-01-01         472800
# 1966-01-01         561200

# %%
# data for Robbery and Murder column
crime.loc[:,['Robbery','Murder']].head()
# Out:
#             Robbery  Murder
# Year
# 1960-01-01   107840    9110
# 1961-01-01   106670    8740
# 1962-01-01   110860    8530
# 1963-01-01   116470    8640
# 1964-01-01   130390    9360

# %%
crime[['Robbery','Murder']].head()
# Out:
#             Robbery  Murder
# Year
# 1960-01-01   107840    9110
# 1961-01-01   106670    8740
# 1962-01-01   110860    8530
# 1963-01-01   116470    8640
# 1964-01-01   130390    9360

# %%
# select the data in rows [3,4,8] and in column ['Robbery','Murder']

# %%
crime.iloc[[3,4,8]][['Robbery','Murder']]
# Out:
#             Robbery  Murder
# Year
# 1963-01-01   116470    8640
# 1964-01-01   130390    9360
# 1968-01-01   262840   13800

# %%
# select only thoese rows where Muders are more than 24k

# %%
crime[crime.Murder >= 24000]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100

# %%
# select the rows where murders are between 20 and 24k

# %%
crime[crime['Murder'].between(20000,24000)].head()
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1974-01-01   211392000  10253400   974720   9278700   20710          55400
# 1975-01-01   213124000  11292400  1039710  10252700   20510          56090
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1974-01-01   442400              456210   3039200        5262500
# 1975-01-01   470500              492620   3265300        5977700
# 1979-01-01   480700              629480   3327700        6601000
# 1980-01-01   565840              672650   3795200        7136900
# 1981-01-01   592910              663900   3779700        7194400
#
#             Vehicle_Theft
# Year
# 1974-01-01         977100
# 1975-01-01        1009600
# ...

# %%
# calculate the mean Muder for each diffrent year

# %%
crime.groupby('Year').mean()[['Murder']].head()
# Out:
#             Murder
# Year
# 1960-01-01    9110
# 1961-01-01    8740
# 1962-01-01    8530
# 1963-01-01    8640
# 1964-01-01    9360

# %%
# sort values in Murder in decending order and then by Voilent in ascending order

# %%
crime.sort_values('Murder',ascending=False).head()
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
# 1992-01-01   672480             1126970   2979900        7915200
# 1990-01-01   639270             1054860   3073900        7945700
# 1994-01-01   618950             1113180   2712800        7879800
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100
# ...

# %%
# wrong way
# crime.sort_values('Murder',ascending=False).sort_values('Violent',ascending=True).head()

# %%
crime.sort_values(by=['Murder','Violent'],ascending=[False,True]).head()
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
# 1992-01-01   672480             1126970   2979900        7915200
# 1990-01-01   639270             1054860   3073900        7945700
# 1994-01-01   618950             1113180   2712800        7879800
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100
# ...

# %%
#

# %%
url123 = 'https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv'

# %%
df12=pd.read_csv(url123,sep=',')

# %%
df12.head()
# Out:
#   Package        Item                                         Title  Rows  \
# 0    boot        acme                        Monthly Excess Returns    60
# 1    boot        aids  Delay in AIDS Reporting in England and Wales   570
# 2    boot   aircondit        Failures of Air-conditioning Equipment    12
# 3    boot  aircondit7        Failures of Air-conditioning Equipment    24
# 4    boot        amis                Car Speeding and Warning Signs  8437
#
#    Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0     3         0            1         0          0          2
# 1     6         1            0         0          0          6
# 2     1         0            0         0          0          1
# 3     1         0            0         0          0          1
# 4     4         1            0         0          0          4
#
#                                                  CSV  \
# 0  https://vincentarelbundock.github.io/Rdatasets...
# ...

# %%
# pivot_table(index='',column='',value='',aggfunc='')
